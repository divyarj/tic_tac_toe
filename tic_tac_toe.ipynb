# %%
print('WELCOME TO TIC TAC TOE GAME !!!!')
choice=int(input("1.START\n2.QUIT"))
if choice==1:
    print("GAME STARTS")
else:
    quit()
def draw(block):
    print('   |     |')
    print( block[0] , ' | ' , block[1] , ' | ' , block[2])
    print('   |     |')
    print('--------------')
    print('   |     |')
    print( block[3] , ' | ' , block[4] , ' | ' , block[5])
    print('   |     |')
    print('--------------')
    print('   |     |')
    print( block[6] , ' | ' , block[7] , ' | ' , block[8])
    print('   |     |')
def win():
    if ((block1[0] == player1 and block1[4] == player1 and block1[8] == player1) or (block1[0] == player1 and block1[1] == player1 and block1[2] == player1) or (block1[0] == player1 and block1[3] == player1 and block1[6] == player1) or (block1[3] == player1 and block1[4] == player1 and block1[5] == player1) or (block1[6] == player1 and block1[7] == player1 and block1[8] == player1) or (block1[1] == player1 and block1[4] == player1 and block1[7] == player1) or (block1[2] == player1 and block1[5] == player1 and block1[8] == player1) or (block1[2] == player1 and block1[4] == player1 and block1[6] == player1)):
        draw(block1);
        print("PLAYER 1 WINS THE GAME")
        quit()
    elif ((block1[0] ==player2 and block1[4] ==player2 and block1[8] == player2) or (block1[0] == player2 and block1[1] == player2 and block1[2] == player2) or (block1[0] == player2 and block1[3] == player2 and block1[6] == player2) or (block1[3] == player2 and block1[4] == player2 and block1[5] == player2) or (block1[6] == player2 and block1[7] == player2 and block1[8] == player2) or (block1[1] == player2 and block1[4] == player2 and block1[7] == player2) or (block1[2] == player2 and block1[5] == player2 and block1[8] == player2) or (block1[2] == player2 and block1[4] == player2 and block1[6] == player2)):
        draw(block1);
        print("PLAYER 2 WINS THE GAME")
        quit()
    else:
        draw(block1);
        print("DRAW MATCH")
        
player1=input("What is your choice ? \n X or O ??")
if player1=='x':
    player2='o'
    print("Since player 1 has chosen 'x' player 2's choice is 'o' by default")
elif player1=='0':
    player2='x'
    print("Since player 1 has chosen 'o' player 2's choice is 'x' by default")
else:
    print("Your option is wrong")
    quit()
print("player 1 and player 2 will be playing alternatively !!!")
print(" ")
block1=[' ',' ',' ',' ',' ',' ',' ',' ',' ']
draw(block1);
count=0
while count<=3:
    i=int(input("player 1-enter your block choice from 0-8"))
    block1[i]=player1
    win();
    i=int(input("player 2-enter your block choice from 0-8"))
    block1[i]=player2
    count=count+1
    win();
i=int(input("player 1-enter your block choice from 0-8"))
block1[i]=player1
win();
# Out:
# WELCOME TO TIC TAC TOE GAME !!!!
# 1.START
# 2.QUIT1
# GAME STARTS
# What is your choice ?
#  X or O ??x
# Since player 1 has chosen 'x' player 2's choice is 'o' by default
# player 1 and player 2 will be playing alternatively !!!
#
#    |     |
#    |     |
#    |     |
# --------------
#    |     |
#    |     |
#    |     |
# --------------
#    |     |
#    |     |
#    |     |
# player 1-enter your block choice from 0-81
#    |     |
#    |  x  |
#    |     |
# --------------
#    |     |
#    |     |
#    |     |
# --------------
#    |     |
#    |     |
#    |     |
# DRAW MATCH
